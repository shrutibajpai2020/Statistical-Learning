# %% [markdown]
# ## Homework Exercise: Shruti Bajpai
#
# 1. Exercise 2 (p.52, Chap.2)
# 2. Exercise 10 (p.56, Chap.2)
# 3. Exercise 3 (p.120, Chap.3),
# 4. Exercise 10 (p.123, Chap.3)
# 5. Exercise 15 (p.126, Chap.3).
#
#
# - (Optional) Section 1’s exercises on Jupyter Notebook

# %% [markdown]
# ### Q1) Chapter 2 Exercise 2
#
# #### Explain whether each scenario is a classification or regression problem, and indicate whether we are most interested in inference or prediction. Finally, provide n and p.

# %% [markdown]
# #### (a) We collect a set of data on the top 500 firms in the US. For each firm we record profit, number of employees, industry and the CEO salary. We are interested in understanding which factors affect CEO salary

# %% [markdown]
# SB Response:
#
# - regression; the quantity of factors that affect the CEO salary and how much are in question here (quantitative)
# - n: 500 (firms in the US)
# - p: 4 variables --> profit, number of employees, industry, and CEO salary

# %% [markdown]
# #### (b) We are considering launching a new product and wish to know whether it will be a success or a failure. We collect data on 20 similar products that were previously launched. For each product we have recorded whether it was a success or failure, price charged for the product, marketing budget, competition price, and ten other variables.

# %% [markdown]
# SB Response:
#
# - classification: wanting to know if the product will be success or failure (success or failure are qualitative)
# - n: 20 observations (similar products previously launched)
# - p: 14 variables --> success/failure, price charged, marketing budget, competitor's pricing, and 10 other variables.

# %% [markdown]
# #### c) We are interested in predicting % change in the USD/Euro exchange rate in relation to the weekly changes in the world
# stock markets. Hence we collect weekly data for all of 2012. For
# each week we record the % change in the USD/Euro, the %
# change in the US market, the % change in the British market,
# and the % change in the German market.

# %% [markdown]
# SB Response:
#
# - regression: predicting changes in exchange rate (quantitative)
# - n: 52 observations
# - p: 4 variables --> % change in USD/Euros, % change in US market, % change in British Market, and % change in German market

# %% [markdown]
# ## Q2) Chapter 2 Exercise 10

# %% [markdown]
# #### This exercise involves the Boston housing data set.
#
# #### (a) To begin, load in the Boston data set. The Boston data set is part of the MASS library in R.
# - library (MASS)
# Now the data set is contained in the object Boston.
# - Boston
# Read about the data set:
# - ?Boston
# How many rows are in this data set? How many columns? What
# do the rows and columns represent?

# %%
library("MASS")

Boston

nrow(Boston) # 506 rows or observations
ncol(Boston) # 14 variables

#columns and rows show 14 features affecting the housing market
# Out:
#     crim     zn   indus chas nox   rm    age   dis    rad tax ptratio black
# 1   0.00632  18.0 2.31  0    0.538 6.575  65.2 4.0900 1   296 15.3    396.90
# 2   0.02731   0.0 7.07  0    0.469 6.421  78.9 4.9671 2   242 17.8    396.90
# 3   0.02729   0.0 7.07  0    0.469 7.185  61.1 4.9671 2   242 17.8    392.83
# 4   0.03237   0.0 2.18  0    0.458 6.998  45.8 6.0622 3   222 18.7    394.63
# 5   0.06905   0.0 2.18  0    0.458 7.147  54.2 6.0622 3   222 18.7    396.90
# 6   0.02985   0.0 2.18  0    0.458 6.430  58.7 6.0622 3   222 18.7    394.12
# 7   0.08829  12.5 7.87  0    0.524 6.012  66.6 5.5605 5   311 15.2    395.60
# 8   0.14455  12.5 7.87  0    0.524 6.172  96.1 5.9505 5   311 15.2    396.90
# 9   0.21124  12.5 7.87  0    0.524 5.631 100.0 6.0821 5   311 15.2    386.63
# 10  0.17004  12.5 7.87  0    0.524 6.004  85.9 6.5921 5   311 15.2    386.71
# 11  0.22489  12.5 7.87  0    0.524 6.377  94.3 6.3467 5   311 15.2    392.52
# ...

# %% [markdown]
# #### b) Make some pairwise scatterplots of the predictors (columns) in this data set. Describe your findings.

# %%
pairs(Boston) #scatterplots correlating to each other; ex: correlation between crime and zn seems low, but crime highly correlates with age, dis, rad, tax, and ptratio. zn correlates highly with indus, nox, age, lstat. 
#indus seems to correlate only with age, dis; nox correlates only with age and dis; it can be noticed that dis correlates highly with lstat and that lstat correlates highly with medv.
# Out:
# plot without title

# %% [markdown]
# #### c) Are any of the predictors associated with per capita crime rate? If so, explain the relationship.

# %%
cor(Boston$crim, Boston$age) #given the p value is greater than 0.05, there is a strong positive relationship
plot(Boston$crim, Boston$age) # it seems that the higher the age, the more likely crime occurs

cor(Boston$crim,Boston$dis) #given the p value is greater than 0.05, there is a strong negative relationship
plot(Boston$crim, Boston$dis) # the plot shows that there is more crime closer to the work-areas

cor(Boston$crim, Boston$rad) #given the p value is greater than 0.05, there is a strong positive relationship
plot(Boston$crim, Boston$rad) # crime is increased when there is more radial highways nearby


cor(Boston$crim, Boston$tax) #given the p value is greater than 0.05, there is a strong positive relationship
plot(Boston$crim, Boston$tax) #too much tax results in a french lifestyle i presume where crime or crime in the form of a strike increases when higher tax is present

cor(Boston$crim, Boston$ptratio) #given the p value is greater than 0.05, there is a strong positive relationship
plot(Boston$crim, Boston$ptratio) # when there is a high pupil to teacher ratio, it seems crimes also increase
# Out:
# [1] 0.3527343
# [1] -0.3796701
# plot without title
# [1] 0.6255051
# plot without title
# [1] 0.5827643
# plot without title
# [1] 0.2899456
# plot without title
# plot without title

# %% [markdown]
# d) Do any of the suburbs of Boston appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios? Comment on the range of each predictor.

# %%
par(mfrow=c(1,3))
hist(Boston$crim[Boston$crim>1], breaks=25) 
# most cities have low crime rates with the histogram being right-skewed, so the higher threshold shows anyone above 20 to have decent amount of crime.


hist(Boston$tax, breaks=25)
#there is a large difference between frequency of crime and tax between 400/450-600; the highest value shows crime occuring at 600; skewedness else is right-skewed if you don't take that large area into account

hist(Boston$ptratio, breaks=25)
#there isn't a great explation of skewedness as mostly it is below fifty, but the high teacher:student ratio to crimes frequency is seen most around 20
# Out:
# Plot with title "Histogram of Boston$ptratio"

# %% [markdown]
# #### e) How many of the suburbs in this data set bound the Charles river?

# %%
dim(subset(Boston, chas == 1))
# Out:
# [1] 35 14

# %% [markdown]
# #### f) What is the median pupil-teacher ratio among the towns in this data set?

# %%
median(Boston$ptratio)
# Out:
# [1] 19.05

# %% [markdown]
# #### g) Which suburb of Boston has lowest median value of owneroccupied homes? What are the values of the other predictors for that suburb, and how do those values compare to the overall ranges for those predictors? Comment on your findings.

# %%
subset(Boston, medv == min(Boston$medv))
summary(Boston)

#area 399 and 406 have lowest based on medv variable; all variables are listed below and based on summary it seems that Boston isn't the safest palce to live, but it isn't as bad either. Personal experience - it's just kinda too cold there.
# Out:
#     crim    zn indus chas nox   rm    age dis    rad tax ptratio black  lstat
# 399 38.3518 0  18.1  0    0.693 5.453 100 1.4896 24  666 20.2    396.90 30.59
# 406 67.9208 0  18.1  0    0.693 5.683 100 1.4254 24  666 20.2    384.97 22.98
#     medv
# 399 5
# 406 5
#       crim                zn             indus            chas
#  Min.   : 0.00632   Min.   :  0.00   Min.   : 0.46   Min.   :0.00000
#  1st Qu.: 0.08204   1st Qu.:  0.00   1st Qu.: 5.19   1st Qu.:0.00000
#  Median : 0.25651   Median :  0.00   Median : 9.69   Median :0.00000
#  Mean   : 3.61352   Mean   : 11.36   Mean   :11.14   Mean   :0.06917
#  3rd Qu.: 3.67708   3rd Qu.: 12.50   3rd Qu.:18.10   3rd Qu.:0.00000
#  Max.   :88.97620   Max.   :100.00   Max.   :27.74   Max.   :1.00000
#       nox               rm             age              dis
#  Min.   :0.3850   Min.   :3.561   Min.   :  2.90   Min.   : 1.130
#  1st Qu.:0.4490   1st Qu.:5.886   1st Qu.: 45.02   1st Qu.: 2.100
# ...

# %% [markdown]
# #### (h) In this data set, how many of the suburbs average more than seven rooms per dwelling?
# More than eight rooms per dwelling?
# Comment on the suburbs that average more than eight rooms per dwelling.

# %%
dim(subset(Boston, rm > 7)) #2

dim(subset(Boston, rm > 8)) #2
summary(subset(Boston, rm > 8))
summary(Boston)
#based on the comparison, it seems increased rooms (greater than 8) tend to have lesser crime and a decreased lower status of the population (lstat) or poor population
# Out:
# [1] 64 14
# [1] 13 14
#       crim               zn            indus             chas
#  Min.   :0.02009   Min.   : 0.00   Min.   : 2.680   Min.   :0.0000
#  1st Qu.:0.33147   1st Qu.: 0.00   1st Qu.: 3.970   1st Qu.:0.0000
#  Median :0.52014   Median : 0.00   Median : 6.200   Median :0.0000
#  Mean   :0.71879   Mean   :13.62   Mean   : 7.078   Mean   :0.1538
#  3rd Qu.:0.57834   3rd Qu.:20.00   3rd Qu.: 6.200   3rd Qu.:0.0000
#  Max.   :3.47428   Max.   :95.00   Max.   :19.580   Max.   :1.0000
#       nox               rm             age             dis
#  Min.   :0.4161   Min.   :8.034   Min.   : 8.40   Min.   :1.801
#  1st Qu.:0.5040   1st Qu.:8.247   1st Qu.:70.40   1st Qu.:2.288
#  Median :0.5070   Median :8.297   Median :78.30   Median :2.894
#  Mean   :0.5392   Mean   :8.349   Mean   :71.54   Mean   :3.430
#  3rd Qu.:0.6050   3rd Qu.:8.398   3rd Qu.:86.50   3rd Qu.:3.652
#  Max.   :0.7180   Max.   :8.780   Max.   :93.90   Max.   :8.907
# ...

# %% [markdown]
# ## Q3) Chapter 3 Exercise 3
#
# ##### Suppose we have a data set with five predictors, X1 =GPA, X2 = IQ, X3 = Gender (1 for Female and 0 forMale), X4 = Interaction between GPA and IQ, and X5 = Interaction between GPA and Gender. The response is starting salary after graduation (in thousands of dollars). Suppose we use least squares to fit the model, and get ˆβ0 = 50, ˆβ1 = 20, ˆβ2 = 0.07, ˆβ3 = 35, ˆβ4 = 0.01, ˆβ5 = −10.

# %% [markdown]
# #### (a) Which answer is correct, and why?
#
# i. For a fixed value of IQ and GPA, males earn more on average than females.
#
# ii. For a fixed value of IQ and GPA, females earn more on average than males.
#
# iii. For a fixed value of IQ and GPA, males earn more on average than females provided that the GPA is high enough.
#
# iv. For a fixed value of IQ and GPA, females earn more on average than males provided that the GPA is high enough.

# %% [markdown]
# SB RESPONSE:
#
# so the total value denoted between the genders calculates as follows:
#
# for men: 50 + 20(k1) + 0.07(k2) + 35 + 0.01(k1 * k2)
#
# for female: 50 + 20(k1) + 0.07((k2)) + 35 + 0.01(k1 * k2) - 10(k1)
#
# After a given threshold for the GPA, it can be seen that the average male earns more, so the answer is iii

# %% [markdown]
# #### b) Predict the salary of a female with IQ of 110 and a GPA of 4.0.

# %%
k1 = 4
k2 = 110
x <- (50 + 20*(k1) + 0.07*(k2) + 35 + 0.01*(k1 * k2) - 10*(k1))
x
# Out:
# [1] 137.1

# %% [markdown]
# #### (c) True or false: Since the coefficient for the GPA/IQ interaction term is very small, there is very little evidence of an interaction effect. Justify your answer.

# %% [markdown]
# SB RESPONSE: The coefficients do not determine if there is correlation; to see if any statistical correlation, one must conduct a Pearson's test and showcase a value below 0.05 to state statistically insignificance.

# %% [markdown]
# ## Q4) Chapter 3 Exercise 10
#
# #### This question should be answered using the Carseats data set.

# %%
install.packages('ISLR')
# Out:
# package 'ISLR' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\bajpa\AppData\Local\Temp\Rtmpk1rq4e\downloaded_packages

# %%
library('ISLR')
attach(Carseats)

# %% [markdown]
# #### (a) Fit a multiple regression model to predict Sales using Price, Urban, and US.

# %%
lm.fit = lm(Sales~Price+Urban+US)
summary(lm.fit)
# Out:
# Call:
# lm(formula = Sales ~ Price + Urban + US)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.9206 -1.6220 -0.0564  1.5786  7.0581
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 13.043469   0.651012  20.036  < 2e-16 ***
# Price       -0.054459   0.005242 -10.389  < 2e-16 ***
# UrbanYes    -0.021916   0.271650  -0.081    0.936
# USYes        1.200573   0.259042   4.635 4.86e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.472 on 396 degrees of freedom
# Multiple R-squared:  0.2393,	Adjusted R-squared:  0.2335
# F-statistic: 41.52 on 3 and 396 DF,  p-value: < 2.2e-16

# %% [markdown]
# #### (b) Provide an interpretation of each coefficient in the model. Be careful—some of the variables in the model are qualitative!

# %% [markdown]
# SB Response:
#
# - for pricing and sales, there is a low correlation below 0.05, showcasing very little correlation; the negative t-value further indicates there to be a negative relationship, signifying that as price increases, sales decreases. this is a true phenomenon noticed in all economic courses.
#
#
# - for urbanyes and sales, there is also a low correlation/no correlation given the extremely high t-statistic p-value.
#
#
# - for USYes, there is a corrleation between stores being located in the US and Sales increase; the statistics show that there is an estimate of 1200.57 increase potential for sales.

# %% [markdown]
# #### (c) Write out the model in equation form, being careful to handle the qualitative variables properly.

# %% [markdown]
# SB Response:
#
# Sales = 13.04 + -0.05*Price + -0.02*UrbanYes + 1.20*USYes

# %% [markdown]
# #### (d) For which of the predictors can you reject the null hypothesis H0 : βj = 0?

# %% [markdown]
# SB Response:
#
# Price and UrbanYes are values for which we can reject the null hypothesis given the p-value shows statistical insignificance.

# %% [markdown]
# #### (e) On the basis of your response to the previous question, fit asmaller model that only uses the predictors for which there is evidence of association with the outcome.

# %%
lm.fit2 = lm(Sales ~ Price + US)
summary(lm.fit2)
# Out:
# Call:
# lm(formula = Sales ~ Price + US)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.9269 -1.6286 -0.0574  1.5766  7.0515
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 13.03079    0.63098  20.652  < 2e-16 ***
# Price       -0.05448    0.00523 -10.416  < 2e-16 ***
# USYes        1.19964    0.25846   4.641 4.71e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.469 on 397 degrees of freedom
# Multiple R-squared:  0.2393,	Adjusted R-squared:  0.2354
# F-statistic: 62.43 on 2 and 397 DF,  p-value: < 2.2e-16

# %% [markdown]
# #### (f) How well do the models in (a) and (e) fit the data?

# %% [markdown]
# SB RESPONSE:
#
# The results are not extremely different for the estimates or the t-statistic p-values, still showing significance.

# %% [markdown]
# #### (g) Using the model from (e), obtain 95% confidence intervals for the coefficient(s).

# %%
confint(lm.fit2)
# Out:
#             2.5 %       97.5 %
# (Intercept) 11.79032020 14.27126531
# Price       -0.06475984 -0.04419543
# USYes        0.69151957  1.70776632

# %% [markdown]
# #### (h) Is there evidence of outliers or high leverage observations in the model from (e)?

# %%
plot(predict(lm.fit2), rstudent(lm.fit2))

#I found this as a potential solution, not sure if it is correct and it is from page 113 in the textbook, but I do not understand the purpose of rstudent() function
# Out:
# plot without title

# %% [markdown]
# ## Q5) Exercise 15
#
# #### This problem involves the Boston data set, which we saw in the lab for this chapter. We will now try to predict per capita crime rate using the other variables in this data set. In other words, per capita crime rate is the response, and the other variables are the predictors.

# %%
Boston
# Out:
#     crim     zn   indus chas nox   rm    age   dis    rad tax ptratio black
# 1   0.00632  18.0 2.31  0    0.538 6.575  65.2 4.0900 1   296 15.3    396.90
# 2   0.02731   0.0 7.07  0    0.469 6.421  78.9 4.9671 2   242 17.8    396.90
# 3   0.02729   0.0 7.07  0    0.469 7.185  61.1 4.9671 2   242 17.8    392.83
# 4   0.03237   0.0 2.18  0    0.458 6.998  45.8 6.0622 3   222 18.7    394.63
# 5   0.06905   0.0 2.18  0    0.458 7.147  54.2 6.0622 3   222 18.7    396.90
# 6   0.02985   0.0 2.18  0    0.458 6.430  58.7 6.0622 3   222 18.7    394.12
# 7   0.08829  12.5 7.87  0    0.524 6.012  66.6 5.5605 5   311 15.2    395.60
# 8   0.14455  12.5 7.87  0    0.524 6.172  96.1 5.9505 5   311 15.2    396.90
# 9   0.21124  12.5 7.87  0    0.524 5.631 100.0 6.0821 5   311 15.2    386.63
# 10  0.17004  12.5 7.87  0    0.524 6.004  85.9 6.5921 5   311 15.2    386.71
# 11  0.22489  12.5 7.87  0    0.524 6.377  94.3 6.3467 5   311 15.2    392.52
# ...

# %% [markdown]
# #### (a) For each predictor, fit a simple linear regression model to predict the response. Describe your results. In which of the models is there a statistically significant association between the predictor and the response? Create some plots to back up your assertions.

# %%
Boston$chas <- factor(Boston$chas, labels = c("N","Y"))

# %%
colnames(Boston)
# Out:
#  [1] "crim"    "zn"      "indus"   "chas"    "nox"     "rm"      "age"
#  [8] "dis"     "rad"     "tax"     "ptratio" "black"   "lstat"   "medv"

# %%
lm.zn = lm(crim~zn)
summary(lm.zn)

lm.indus = lm(crim~indus)
summary(lm.indus)

lm.chas = lm(crim~chas)
summary(lm.chas)

lm.nox = lm(crim~nox)
summary(lm.nox)

lm.room = lm(crim~rm)
summary(lm.room)

lm.age = lm(crim~age)
summary(lm.age)

lm.dis = lm(crim~dis)
summary(lm.dis)

lm.radius = lm(crim~rad)
summary(lm.rad)

lm.tax = lm(crim~tax)
summary(lm.tax)

lm.studentteach = lm(crim~ptratio)
summary(lm.ptratio)

lm.black = lm(crim~black)
summary(lm.black)

lm.povertylstat = lm(crim~lstat)
summary(lm.povertylstat)

lm.mdev = lm(crim~mdev)
summary(lm.mdev)

#NOT sure why this doesn't work, but based on p-value you could tell if it was statistically significant or not
# Out:
# Error in eval(predvars, data, env): object 'crim' not found
# Traceback:
#
# 1. lm(crim ~ indus)
# 2. eval(mf, parent.frame())
# 3. eval(mf, parent.frame())
# 4. stats::model.frame(formula = crim ~ indus, drop.unused.levels = TRUE)
# 5. model.frame.default(formula = crim ~ indus, drop.unused.levels = TRUE)
# 6. eval(predvars, data, env)
# 7. eval(predvars, data, env)

# %% [markdown]
# #### (b) Fit a multiple regression model to predict the response using all of the predictors. Describe your results. For which predictors can we reject the null hypothesis H0 : βj = 0?

# %%
lm.boston = lm(crim~., data=Boston)
summary(lm.boston)

#zn, dis, rad, black and medv all have values below 0.05 for p-value (hence the astrics) and therefore we can reject null hypothesis
# Out:
# Call:
# lm(formula = crim ~ ., data = Boston)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -9.924 -2.120 -0.353  1.019 75.051
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  17.033228   7.234903   2.354 0.018949 *
# zn            0.044855   0.018734   2.394 0.017025 *
# indus        -0.063855   0.083407  -0.766 0.444294
# chasY        -0.749134   1.180147  -0.635 0.525867
# nox         -10.313535   5.275536  -1.955 0.051152 .
# rm            0.430131   0.612830   0.702 0.483089
# age           0.001452   0.017925   0.081 0.935488
# dis          -0.987176   0.281817  -3.503 0.000502 ***
# rad           0.588209   0.088049   6.680 6.46e-11 ***
# tax          -0.003780   0.005156  -0.733 0.463793
# ptratio      -0.271081   0.186450  -1.454 0.146611
# black        -0.007538   0.003673  -2.052 0.040702 *
# lstat         0.126211   0.075725   1.667 0.096208 .
# medv         -0.198887   0.060516  -3.287 0.001087 **
# ---
# ...

# %% [markdown]
# #### (c) How do your results from (a) compare to your results from (b)? Create a plot displaying the univariate regression coefficients from (a) on the x-axis, and the multiple regression coefficients from (b) on the y-axis. That is, each predictor is displayed as a single point in the plot. Its coefficient in a simple linear regression model is shown on the x-axis, and its coefficient estimate in the multiple linear regression model is shown on the y-axis.

# %%
### I"m not sure how to do this one.

# %% [markdown]
# #### (d) Is there evidence of non-linear association between any of the predictors and the response? To answer this question, for each predictor X, fit a model of the form Y = β0 + β1X + β2X2 + β3X3 + .

# %%
#(e)
lm.fit2 = lm(Sales ~ Price + US)
summary(lm.fit2)
# Out:
# Call:
# lm(formula = Sales ~ Price + US)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.9269 -1.6286 -0.0574  1.5766  7.0515
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 13.03079    0.63098  20.652  < 2e-16 ***
# Price       -0.05448    0.00523 -10.416  < 2e-16 ***
# USYes        1.19964    0.25846   4.641 4.71e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.469 on 397 degrees of freedom
# Multiple R-squared:  0.2393,	Adjusted R-squared:  0.2354
# F-statistic: 62.43 on 2 and 397 DF,  p-value: < 2.2e-16

# %% [markdown]
# ### (f) both models fit similarly based on their R squared and RSE values

# %%
#(g)
confint(lm.fit2)
# Out:
#             2.5 %       97.5 %
# (Intercept) 11.79032020 14.27126531
# Price       -0.06475984 -0.04419543
# USYes        0.69151957  1.70776632

# %% [markdown]
# ### (h) There is no evidence of outliers based on part E
